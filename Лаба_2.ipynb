# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanova-Daria/Labworks/blob/main/%D0%9B%D0%B0%D0%B1%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2.1.11

# %%
import matplotlib.pyplot as plt
fig, ax =plt.subplots()
import numpy as np
x = np.arange(0, 5, 0.2)
ax.plot(x, x**3, '^r')
ax.plot(x, x**2, 'sb')
ax.plot(x, x, '--g')
plt.show()

# %% [markdown]
# # 2.2.11
# Напишите программу на Python для создания гистограммы из DataFrame.
# Примерный фрейм данных:
# ABCDE
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2

# %%
import matplotlib.pyplot as plt
fig, ax =plt.subplots()
import numpy as np
data = [[4,2,4,2,2],[8,3,7,6,4],[5,4,4,4,3],[7,2,7,8,3],[6,6,8,6,2]]
s = np.array([2,4,6,8,10])
ax.bar(s-0.5,data[0], color = 'b',width = 0.25, label = 'a')
ax.bar(s - 0.25,data[1], color = 'g',width = 0.25, label = 'b')
ax.bar(s,data[2], color = 'r',width = 0.25, label = 'c')
ax.bar(s + 0.25,data[3], color = 'pink',width = 0.25, label = 'd')
ax.bar(s + 0.5,data[4], color = 'purple',width = 0.25, label = 'e')
ax.legend()
ax.minorticks_on()
ax.grid(which='major',color = 'g',linewidth = 0.5)
ax.grid(which='minor', color = 'k', linestyle = ':')
plt.show()

# %% [markdown]
# # 2.3.2.
# Напишите программирование на Python для создания круговой диаграммы с названием популярности языков программирования.
# Пример данных:
# Языки программирования: Java, Python, PHP, JavaScript, C #, C ++
# Популярность: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
from matplotlib import pyplot as plt
import numpy as np
fig, ax = plt.subplots()
langs = ['C', 'C++','Java', 'Python', 'PHP','JavaScript']
students = [7.7, 6.7, 22.2, 17.6, 8.8, 8]
ax.pie(students, labels = langs, autopct = '%1.1f%%', shadow=True, explode = (0, 0, 0.07, 0,0,0))
plt.show()

# %% [markdown]
# # 2.4.3
# Напишите программу на Python для построения точечной диаграммы с использованием случайных распределений для создания шаров разных размеров.

# %%
from matplotlib import pyplot as plt
import numpy as np
fig, ax = plt.subplots()
x = np.random.rand(20)
y = np.random.rand(20)
ax.scatter(x,y,s=250*np.random.rand(20),c=np.random.rand(20) )

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file"{name}" with lenght {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e03c594d-e67f-43f8-9864-ece2d8ac05aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e03c594d-e67f-43f8-9864-ece2d8ac05aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hhh.xlsx to hhh.xlsx
# User uploaded file"hhh.xlsx" with lenght 1312427 bytes

# %% [markdown]
# # 2.5.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import openpyxl

fig, axes = plt.subplots(2,2)
table = pd.read_excel('hhh.xlsx')
x = table.values[:, 2]
s = table.values[:, 1]
axes[1,0].bar(s, x)

o = table.values[:, 2]
y = table.values[:, 12]
axes[1,1].plot(y,o)

p = table.values[:, 3]
i = 0
f = 0
for t in p:
  if t == 'Male':
    i = i+1
  elif t == 'Female':
    f = f+1
t = [i,f]
axes[0,1].pie(t,labels = ['Male','Female'])
x = table.values[:, 0]
s = table.values[:, 12]
axes[0,0].bar(s, x)


plt.show()
